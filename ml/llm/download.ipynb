# %%
! pip install huggingface-hub openai

# %%
from huggingface_hub import hf_hub_download

# Загрузка конкретного файла модели
model_path = hf_hub_download(
    repo_id="unsloth/Qwen3-4B-Instruct-2507-GGUF",
    filename="Qwen3-4B-Instruct-2507-Q4_K_M.gguf",  # укажите точное имя файла
    local_dir="./models",  # папка для сохранения
    local_dir_use_symlinks=False
)

print(f"Модель загружена в: {model_path}")
# Out:
# Модель загружена в: models/Qwen3-4B-Instruct-2507-Q4_K_M.gguf
